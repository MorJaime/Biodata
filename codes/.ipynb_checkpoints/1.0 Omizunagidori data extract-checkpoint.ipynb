# %%
import os
import glob
import math
import pandas as pd
import numpy as np
import itertools
import random
import requests
import xml.etree.ElementTree as ET
import csv

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.patches as patches

import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from keras.utils import np_utils
from keras.utils.vis_utils import model_to_dot
from keras.callbacks import EarlyStopping
from IPython.display import SVG

#import tensorflow_probability as tfp


from sklearn.metrics import classification_report, confusion_matrix
from sklearn import preprocessing
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer, normalize
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

from ipywidgets import FloatProgress
from IPython.display import display

#fig_width = 12
plt.rcParams["font.size"] = 40
plt.rcParams['axes.labelsize'] = 40
plt.rcParams['axes.labelweight'] = 'bold'
#plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
#plt.rcParams.keys()
# Out:
# Using TensorFlow backend.

# %%
def time_change(acc_df):
    df=acc_df['timestamp']
    df1=df.astype(np.int64)
    acc_df['timestamp']=df1/1000000
    acc_df['timestamp'] = acc_df['timestamp'].map(lambda x: int(x))
    return acc_df

# %% [markdown]
# # Label select

# %%
label_omizu2018 = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\labels\Omizunagidori2018_labels_20230317_152858.xml"
label_omizu2019 = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\labels\Omizunagidori2019_labels_20230317_152908.xml"
label_omizu2020 = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\labels\Omizunagidori2020_labels_20230317_153206.xml"
label_omizu2021 = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\labels\Omizunagidori2021_labels_20230317_153231.xml"
label_omizu2022 = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\labels\Omizunagidori2022_labels_20230317_153302.xml"

label_paths_o = [label_omizu2018,label_omizu2019,label_omizu2020,label_omizu2021,label_omizu2022]

# %%
label_umineko2018 = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\labels\Umineko2018_labels_20230317_153338.xml'
label_umineko2019 = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\labels\Umineko2019_labels_20230317_153433.xml'
label_umineko2022 = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\labels\Umineko2022_labels_20230317_153451.xml'

label_paths_u = [label_umineko2018,label_umineko2019,label_umineko2022]

# %%
def make_labels(paths, label_wr_dir = r'G:\JaimeMorales\Codes\biodata\codes\data\labels', fn_end = 17):
    
    for path in paths:
        label_path = path
        label_dir_p, label_fn = os.path.split(label_path)
        wr_fn = label_fn[:fn_end]
        tree = ET.parse(label_path)
        root = tree.getroot()
        filename = os.path.join(label_wr_dir,wr_fn+'_labels.csv')
        
        with open(filename,"w") as f:            
            csv_writer = csv.writer(f)
            header = ["event_type","start", "end"]
            csv_writer.writerow(header)
            for labellist in root.iter("labellist"):
                timestampStart = labellist[1].text
                timestampStart = timestampStart.replace('-','')
                timestampStart = timestampStart.replace('T',' ')      
                timestampStart = timestampStart.replace('Z','')
                timestampEnd = labellist[2].text
                timestampEnd = timestampEnd.replace('-','')
                timestampEnd = timestampEnd.replace('T',' ')
                timestampEnd = timestampEnd.replace('Z','')

                row = [labellist[0].text, labellist[1].text, labellist[2].text]
                row = [labellist[0].text,timestampStart,timestampEnd]
                csv_writer.writerow(row)
            
        print('created labels for >>> ',filename)
        
    return

# %% [markdown]
# # Create label files

# %%
make_labels(label_paths_o, fn_end = 17)
# Out:
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Omizunagidori2018_labels.csv
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Omizunagidori2019_labels.csv
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Omizunagidori2020_labels.csv
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Omizunagidori2021_labels.csv
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Omizunagidori2022_labels.csv

# %%
make_labels(label_paths_u, fn_end = 11)
# Out:
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Umineko2018_labels.csv
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Umineko2019_labels.csv
# created labels for >>>  G:\JaimeMorales\Codes\biodata\codes\data\labels\Umineko2022_labels.csv

# %% [markdown]
# # Omizunagidori

# %% [markdown]
# ## 2017 file names

# %%
Y17_LB01_fn = r"G:\JaimeMorales\Codes\biodata\database\export\Omizunagidori2017_raw_data_9B16929_lb0001.CSV"
Y17_LB02_fn = r"G:\JaimeMorales\Codes\biodata\database\export\Omizunagidori2017_raw_data_9B34082_lb0002.CSV"
Y17_LB03_fn = r"G:\JaimeMorales\Codes\biodata\database\export\Omizunagidori2017_raw_data_9B34968_lb0003.CSV"
Y17_LB04_fn = r"G:\JaimeMorales\Codes\biodata\database\export\Omizunagidori2017_raw_data_9B36321_lb0004.CSV"
Y17_data_all_fn = [Y17_LB01_fn, Y17_LB02_fn, Y17_LB03_fn, Y17_LB04_fn]
Y17_save_folder = r"G:\JaimeMorales\Codes\biodata\codes\data\Y17"

# %% [markdown]
# ## 2018 file names

# %%
Y18_LB01_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B16995_lb0001.CSV"
Y18_LB02_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B24590_lb0002.CSV"
Y18_LB03_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B34075_lb0003.CSV"
Y18_LB04_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36347_lb0004.CSV"
Y18_LB05_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36360_lb0005.CSV"
Y18_LB06_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36365_lb0006.CSV"
Y18_LB07_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36547_lb0007.CSV"
Y18_LB08_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36577_lb0008.CSV"
Y18_LB09_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36578_lb0009.CSV"
Y18_LB10_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36580_lb0010.CSV"
Y18_LB11_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2018_raw_data_9B36586_lb0011.CSV"
Y18_data_all_fn = [Y18_LB01_fn,Y18_LB02_fn,Y18_LB03_fn,Y18_LB04_fn,Y18_LB05_fn,Y18_LB06_fn,Y18_LB07_fn,Y18_LB08_fn,Y18_LB09_fn,Y18_LB10_fn,Y18_LB11_fn]
Y18_save_folder = r"G:\JaimeMorales\Codes\biodata\codes\data\Y18"

# %% [markdown]
# ## 2019 file names

# %%
Y19_LB01_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2019_raw_data_C5_lbs0001.csv"
Y19_data_all_fn = [Y19_LB01_fn]
Y19_save_folder = r"G:\JaimeMorales\Codes\biodata\codes\data\Y19"

# %% [markdown]
# ## 2020 file names

# %%
Y20_LB01_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2020_raw_data_20MZ01_20200826_lbs0001.csv"
Y20_LB02_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2020_raw_data_20MZ03_20200909_lbs0002.csv"
Y20_LB03_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2020_raw_data_20MZ09_20201005_lbs0003.csv"
Y20_LB04_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2020_raw_data_UNK001_20200831_lbs0004.csv"
Y20_LB05_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2020_raw_data_UNK001_20200914_lbs0005.csv"
Y20_LB06_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2020_raw_data_UNK003_20200901_lbs0006.csv"
Y20_data_all_fn = [Y20_LB01_fn,Y20_LB02_fn,Y20_LB03_fn,Y20_LB04_fn,Y20_LB05_fn,Y20_LB06_fn]
Y20_save_folder = r"G:\JaimeMorales\Codes\biodata\codes\data\Y20"

# %% [markdown]
# ## 2021 file names

# %%
Y21_LB01_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2021_raw_data_LOB01_lbs0001.csv"
Y21_LB02_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2021_raw_data_LOB02_lbs0002.csv"
Y21_LB03_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2021_raw_data_LOB03_lbs0003.csv"
Y21_data_all_fn = [Y21_LB01_fn,Y21_LB02_fn,Y21_LB03_fn]
Y21_save_folder = r"G:\JaimeMorales\Codes\biodata\codes\data\Y21"

# %% [markdown]
# ## 2022 file names

# %%
Y22_LB01_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB01_lbs0001.CSV"
Y22_LB02_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB02_lbs0002.CSV"
Y22_LB03_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB03_lbs0003.CSV"
Y22_LB04_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB04_lbs0004.CSV"
Y22_LB05_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB05_lbs0005.CSV"
Y22_LB07_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB07_lbs0014.CSV"
Y22_LB08_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB08_lbs0006.csv"
Y22_LB09_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB09_lbs0007.CSV"
Y22_LB10_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB10_lbs0012.CSV"
Y22_LB11_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB11_lbs0008.CSV"
Y22_LB13_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB13_lbs0013.CSV"
Y22_LB14_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB14_lbs0009.CSV"
Y22_LB15_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB15_lbs0010.CSV"
Y22_LB17_fn = r"G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Omizunagidori\Omizunagidori2022_raw_data_LB17_lbs0011.csv"
Y22_data_all_fn = [Y22_LB01_fn,Y22_LB02_fn,Y22_LB03_fn,Y22_LB04_fn,Y22_LB05_fn,Y22_LB07_fn,Y22_LB08_fn,Y22_LB09_fn,Y22_LB10_fn,Y22_LB11_fn,Y22_LB13_fn,Y22_LB14_fn,Y22_LB15_fn,Y22_LB17_fn]
Y22_save_folder = r"G:\JaimeMorales\Codes\biodata\codes\data\Y22"

# %% [markdown]
# # Umineko

# %% [markdown]
# ## 2018 file names

# %%
Y18_LB01_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB07_lb0001.csv'
Y18_LB02_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB08_lb0002.csv'
Y18_LB03_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB09_lb0003.csv'
Y18_LB04_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB10_lb0004.csv'
Y18_LB05_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB11_lb0005.csv'
Y18_LB06_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB12_lb0006.csv'
Y18_LB07_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB13_lb0007.csv'
Y18_LB08_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB14_lb0008.csv'
Y18_LB09_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB15_lb0009.csv'
Y18_LB10_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB16_lb0010.csv'
Y18_LB11_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2018_raw_data_LB17_lb0011.csv'
Y18_data_all_fn_U = [Y18_LB01_fn_U,Y18_LB02_fn_U,Y18_LB03_fn_U,Y18_LB04_fn_U,Y18_LB05_fn_U,Y18_LB06_fn_U,Y18_LB07_fn_U,Y18_LB08_fn_U,Y18_LB09_fn_U,Y18_LB10_fn_U,Y18_LB11_fn_U]
Y18_save_folder_U = r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18"

# %% [markdown]
# ## 2019 file names

# %%
Y19_LB01_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB01_lb0001.csv'
Y19_LB02_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB02_lb0002.csv'
Y19_LB03_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB03_lb0003.csv'
Y19_LB04_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB04_lb0004.csv'
Y19_LB05_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB05_lb0005.csv'
Y19_LB06_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB06_lb0006.csv'
Y19_LB07_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB07_lb0007.csv'
Y19_LB08_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB09_lb0008.csv'
Y19_LB09_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB10_lb0009.csv'
Y19_LB10_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB11_lb0010.csv'
Y19_LB11_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB12_lb0011.csv'
Y19_LB12_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB13_lb0012.csv'
Y19_LB13_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB14_lb0013.csv'
Y19_LB14_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LBS01_lb0014.csv'
Y19_LB15_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LBS02_lb0015.csv'
Y19_LB16_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LBS03_lb0016.csv'
Y19_LB17_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2019_raw_data_2019LB08_lb0017.csv'
Y19_data_all_fn_U = [Y18_LB01_fn_U,Y18_LB02_fn_U,Y18_LB03_fn_U,Y18_LB04_fn_U,Y18_LB05_fn_U,Y18_LB06_fn_U,Y18_LB07_fn_U,Y18_LB08_fn_U,Y18_LB09_fn_U,Y18_LB10_fn_U,Y18_LB11_fn_U]
Y19_save_folder_U = r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19"

# %% [markdown]
# ## 2022 file names

# %%
Y22_LB01_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2022_raw_data_LB02_lbs0001.csv'
Y22_LB02_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2022_raw_data_LB03_lbs0002.csv'
Y22_LB03_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2022_raw_data_LB08_lbs0003.csv'
Y22_LB04_fn_U = r'G:\JaimeMorales\Codes\biodata\BiotaggerData\export\Umineko\Umineko2022_raw_data_LB09_lbs0004.csv'
Y22_data_all_fn_U = [Y22_LB01_fn_U,Y22_LB02_fn_U,Y22_LB03_fn_U,Y22_LB04_fn_U]
Y22_save_folder_U = r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22"

# %% [markdown]
# # Sensor specific dataframe creation

# %%
def separate_by_sensor(filename, save_folder, sensor='acc', time_format="%Y%m%d_%H:%M:%S.%f"):
    data = pd.read_csv(filename, parse_dates=["timestamp"])    
    data["timestamp"] = pd.to_datetime(data["timestamp"],format=time_format)
    
    if sensor == 'acc':
        new_df = data.drop(['logger_id', 'latitude', 'longitude', 'gps_status', 'gyro_x', 'gyro_y', 'gyro_z', 'mag_x', 'mag_y', 'mag_z', 'illumination', 'pressure', 'temperature'],axis=1)
    else:
        new_df = data
        
    name = filename[-11:-4]
    name = name.replace('_','')
    name = name.replace('00','')
    save_name = os.path.join(save_folder,name+'_acc.csv')
    new_df.to_csv(save_name,index=False)
    
    data_df = pd.read_csv(save_name)
    l = []
    for i in range(len(data)):
        l.append(data_df['timestamp'][i].replace('+00:00',''))
    data_df['timestamp'] = l
    #data_df['timestamp'][0] = data_df['timestamp'][0]+'.000000'
    
    #data_df = pd.to_datetime(data_df["timestamp"],format=time_format)
    
    #data_df = time_change(data_df)
    
    #data_df.to_csv(os.path.join(save_folder,name+'t_acc.csv'),index=False)

# %% [markdown]
# # Create acc files - OMIZUNAGIDORI

# %%
for fn in Y18_data_all_fn:
    separate_by_sensor(fn, Y18_save_folder)

# %%
for fn in Y19_data_all_fn:
    separate_by_sensor(fn, Y19_save_folder)

# %%
for fn in Y20_data_all_fn:
    separate_by_sensor(fn, Y20_save_folder)

# %%
for fn in Y21_data_all_fn:
    separate_by_sensor(fn, Y21_save_folder)

# %%
for fn in Y22_data_all_fn:
    separate_by_sensor(fn, Y22_save_folder)

# %% [markdown]
# # Create acc files - UMINEKO

# %%
for fn in Y18_data_all_fn_U:
    separate_by_sensor(fn, Y18_save_folder_U)

# %%
for fn in Y19_data_all_fn_U:
    separate_by_sensor(fn, Y19_save_folder_U)

# %%
for fn in Y22_data_all_fn_U:
    separate_by_sensor(fn, Y22_save_folder_U)

# %% [markdown]
# # Combine data by year

# %%
def join_by_year(read_dir):
    pre_df_fn = os.listdir(read_dir)[0]
    pre_df = pd.read_csv(os.path.join(read_dir, pre_df_fn),parse_dates=["timestamp"])
    all_bird_df = pd.DataFrame(columns = pre_df.columns)
    for file in os.listdir(read_dir):
        if file.endswith(".csv"):
            print(os.path.join(read_dir, file))
            path = os.path.join(read_dir, file)
            df = pd.read_csv(path,parse_dates=["timestamp"])
            all_bird_df = all_bird_df.append(df, ignore_index=True)
        
    birds = list(all_bird_df.drop_duplicates(subset=['animal_tag'],keep = 'first')['animal_tag'])
    print(birds)
    
    all_bird_df.to_csv(os.path.join(read_dir, 'all_bird_df.csv'),index=False)
    
    return all_bird_df

# %% [markdown]
# ## Omizunagidori

# %%
all_bird_df_Y18 = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\Y18")
all_bird_df_Y18
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb03_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb04_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb05_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb06_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb07_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb08_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb09_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb10_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y18\lb11_acc.csv
# ['9B16995', '9B24590', '9B34075', '9B36347', '9B36360', '9B36365', '9B36547', '9B36577', '9B36578', '9B36580', '9B36586']
#         animal_tag                        timestamp     acc_x     acc_y  \
# 0          9B16995        2018-09-08 20:13:00+00:00  0.928223  0.774170
# ...

# %%
all_bird_df_Y18.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y18.dropna(inplace = True)
all_bird_df_Y18.reset_index(inplace = True)
all_bird_df_Y18.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y18.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\Y18\all_bird_df_Y18_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y18.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['stationary',
#  'flight_take_off',
#  'flight_cruising',
#  'unknown',
#  'bathing',
#  'surface_seizing']

# %%
all_bird_df_Y19 = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\Y19")
all_bird_df_Y19
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\Y19\lbs01_acc.csv
# ['C5']
#         animal_tag                        timestamp     acc_x     acc_y  \
# 0               C5        2019-08-21 20:13:01+00:00  0.015625 -0.066406
# 1               C5 2019-08-21 20:13:01.040000+00:00  0.089844 -0.121094
# 2               C5 2019-08-21 20:13:01.080000+00:00 -0.187500 -0.183594
# 3               C5 2019-08-21 20:13:01.100000+00:00  0.000000  0.000000
# 4               C5 2019-08-21 20:13:01.104000+00:00  0.000000  0.000000
# ...            ...                              ...       ...       ...
# 1454484         C5 2019-08-22 09:14:59.800000+00:00 -0.101563 -0.417969
# 1454485         C5 2019-08-22 09:14:59.840000+00:00 -0.054688 -0.093750
# 1454486         C5 2019-08-22 09:14:59.880000+00:00 -0.117188 -0.140625
# 1454487         C5 2019-08-22 09:14:59.920000+00:00 -0.125000 -0.222656
# 1454488         C5 2019-08-22 09:14:59.960000+00:00 -0.144531  0.046875
#
# ...

# %%
labels = list(all_bird_df_Y19.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# [nan,
#  'stationary',
#  'bathing',
#  'flight_cruising',
#  'flight_take_off',
#  'surface_seizing',
#  'preening',
#  'foraging_dive',
#  'unknown',
#  'body_shaking']

# %%
all_bird_df_Y19.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y19.dropna(inplace = True)
all_bird_df_Y19.reset_index(inplace = True)
all_bird_df_Y19.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y19.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\Y19\all_bird_df_Y19_WL.csv",index=False)

# %%
all_bird_df_Y20 = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\Y20")
all_bird_df_Y20
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\Y20\lbs01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y20\lbs02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y20\lbs03_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y20\lbs04_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y20\lbs05_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y20\lbs06_acc.csv
# ['20MZ01_20200826', '20MZ03_20200909', '20MZ09_20201005', 'UNK001_20200831', 'UNK001_20200914', 'UNK003_20200901']
#               animal_tag                        timestamp     acc_x     acc_y  \
# 0        20MZ01_20200826        2020-08-21 20:13:01+00:00  0.046875  0.148438
# 1        20MZ01_20200826 2020-08-21 20:13:01.032000+00:00  0.121094  0.484375
# 2        20MZ01_20200826 2020-08-21 20:13:01.064000+00:00  0.109375  0.507813
# 3        20MZ01_20200826 2020-08-21 20:13:01.096000+00:00  0.070313  0.468750
# 4        20MZ01_20200826 2020-08-21 20:13:01.129000+00:00  0.007813  0.433594
# ...

# %%
all_bird_df_Y20.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y20.dropna(inplace = True)
all_bird_df_Y20.reset_index(inplace = True)
all_bird_df_Y20.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y20.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\Y20\all_bird_df_Y20_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y20.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['stationary',
#  'bathing',
#  'flight_take_off',
#  'flight_cruising',
#  'foraging_dive',
#  'surface_seizing',
#  'unknown',
#  'preening',
#  'body_shaking']

# %%
all_bird_df_Y21 = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\Y21")
all_bird_df_Y21
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\Y21\lbs01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y21\lbs02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y21\lbs03_acc.csv
# ['LOB01', 'LOB02', 'LOB03']
#         animal_tag                        timestamp     acc_x     acc_y  \
# 0            LOB01        2021-08-19 10:46:46+00:00 -0.207031 -0.027344
# 1            LOB01 2021-08-19 10:46:46.032000+00:00 -0.207031 -0.027344
# 2            LOB01 2021-08-19 10:46:46.064000+00:00 -0.207031 -0.031250
# 3            LOB01 2021-08-19 10:46:46.096000+00:00 -0.207031 -0.027344
# 4            LOB01 2021-08-19 10:46:46.129000+00:00 -0.207031 -0.031250
# ...            ...                              ...       ...       ...
# 7292032      LOB03 2021-09-03 09:14:59.838000+00:00  0.167969  0.144531
# 7292033      LOB03 2021-09-03 09:14:59.870000+00:00  0.167969  0.164063
# 7292034      LOB03 2021-09-03 09:14:59.903000+00:00  0.171875  0.167969
# ...

# %%
all_bird_df_Y21.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y21.dropna(inplace = True)
all_bird_df_Y21.reset_index(inplace = True)
all_bird_df_Y21.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y21.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\Y21\all_bird_df_Y21_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y21.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['unknown',
#  'flight_take_off',
#  'flight_cruising',
#  'stationary',
#  'foraging_dive',
#  'surface_seizing',
#  'preening']

# %%
all_bird_df_Y22 = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\Y22")
all_bird_df_Y22
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs03_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs04_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs05_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs06_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs07_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs08_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs09_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs10_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs11_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs12_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs13_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\Y22\lbs14_acc.csv
# ['LB01', 'LB02', 'LB03', 'LB04', 'LB05', 'LB08', 'LB09', 'LB11', 'LB14', 'LB15', 'LB17', 'LB10', 'LB13', 'LB07']
# ...

# %%
all_bird_df_Y22.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y22.dropna(inplace = True)
all_bird_df_Y22.reset_index(inplace = True)
all_bird_df_Y22.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y22.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\Y22\all_bird_df_Y22_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y22.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['unknown',
#  'stationary',
#  'flight_take_off',
#  'flight_cruising',
#  'surface_seizing',
#  'foraging_dive',
#  'preening',
#  'bathing']

# %% [markdown]
# ## Umineko

# %%
all_bird_df_Y18u = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18")
all_bird_df_Y18u
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb03_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb04_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb05_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb06_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb07_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb08_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb09_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb10_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\lb11_acc.csv
# ['LB07', 'LB08', 'LB09', 'LB10', 'LB11', 'LB12', 'LB13', 'LB14', 'LB15', 'LB16', 'LB17']
#         animal_tag                        timestamp     acc_x     acc_y  \
# 0             LB07        2018-05-25 01:02:05+00:00  0.811523 -0.028564
# ...

# %%
all_bird_df_Y18u.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y18u.dropna(inplace = True)
all_bird_df_Y18u.reset_index(inplace = True)
all_bird_df_Y18u.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y18u.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y18\all_bird_df_Y18_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y18u.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['ground_stationary',
#  'unknown',
#  'flying_active',
#  'flying_passive',
#  'stationary',
#  'bathing_poss',
#  'bathing',
#  'preening',
#  'foraging_insect_poss',
#  'ground_active',
#  'foraging_poss',
#  'forgaing_insect',
#  'poss_foraging']

# %%
all_bird_df_Y19u = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19")
all_bird_df_Y19u
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb03_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb04_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb05_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb06_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb07_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb08_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb09_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb10_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\lb11_acc.csv
# ['LB07', 'LB08', 'LB09', 'LB10', 'LB11', 'LB12', 'LB13', 'LB14', 'LB15', 'LB16', 'LB17']
#         animal_tag                        timestamp     acc_x     acc_y  \
# 0             LB07        2018-05-25 01:02:05+00:00  0.811523 -0.028564
# ...

# %%
all_bird_df_Y19u.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y19u.dropna(inplace = True)
all_bird_df_Y19u.reset_index(inplace = True)
all_bird_df_Y19u.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y19u.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y19\all_bird_df_Y19_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y19u.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['ground_stationary',
#  'unknown',
#  'flying_active',
#  'flying_passive',
#  'stationary',
#  'bathing_poss',
#  'bathing',
#  'preening',
#  'foraging_insect_poss',
#  'ground_active',
#  'foraging_poss',
#  'forgaing_insect',
#  'poss_foraging']

# %%
all_bird_df_Y22u = join_by_year(r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22")
all_bird_df_Y22u
# Out:
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22\lbs01_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22\lbs02_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22\lbs03_acc.csv
# G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22\lbs04_acc.csv
# ['LB02', 'LB03', 'LB08', 'LB09']
#         animal_tag                        timestamp     acc_x     acc_y  \
# 0             LB02        2022-05-08 00:04:01+00:00 -0.351563  0.101563
# 1             LB02 2022-05-08 00:04:01.032000+00:00 -0.449219  0.136719
# 2             LB02 2022-05-08 00:04:01.064000+00:00 -0.457031  0.101563
# 3             LB02 2022-05-08 00:04:01.096000+00:00 -0.453125  0.046875
# 4             LB02 2022-05-08 00:04:01.129000+00:00 -0.542969 -0.199219
# ...            ...                              ...       ...       ...
# 4057058       LB09 2022-05-17 11:57:58.838000+00:00 -0.250000 -0.230469
# 4057059       LB09 2022-05-17 11:57:58.870000+00:00 -0.242188 -0.234375
# ...

# %%
all_bird_df_Y22u.drop(['activity_class'],axis = 1,inplace = True)
all_bird_df_Y22u.dropna(inplace = True)
all_bird_df_Y22u.reset_index(inplace = True)
all_bird_df_Y22u.drop(['index'],axis = 1,inplace = True)
all_bird_df_Y22u.to_csv(r"G:\JaimeMorales\Codes\biodata\codes\data\umineko\Y22\all_bird_df_Y22_WL.csv",index=False)

# %%
labels = list(all_bird_df_Y22u.drop_duplicates(subset=['label'],keep = 'first')['label'])
labels
# Out:
# ['flying_active',
#  'flying_passive',
#  'unknown',
#  'stationary',
#  'bathing',
#  'foraging_fish_poss',
#  'body_shaking',
#  'preening',
#  'ground_stationary']

# %% [markdown]
# # Vizualize transformed data
# ## Load DataFrame

# %%
viz_path = r"G:\JaimeMorales\Codes\biodata\codes\data\Y22\all_bird_df_Y22_WL.csv"

# %%
viz_df = pd.read_csv(viz_path,parse_dates=["timestamp"])
viz_df
# Out:
#        animal_tag                        timestamp     acc_x     acc_y  \
# 0            LB01 2022-08-26 20:24:05.548000+00:00  0.683594  1.324219
# 1            LB01 2022-08-26 20:24:05.580000+00:00 -0.367188  0.066406
# 2            LB01 2022-08-26 20:24:05.612000+00:00 -2.488281  0.156250
# 3            LB01 2022-08-26 20:24:05.645000+00:00 -2.980469 -0.390625
# 4            LB01 2022-08-26 20:24:05.677000+00:00 -1.070313 -0.187500
# ...           ...                              ...       ...       ...
# 655902       LB13 2022-09-13 23:55:44.870000+00:00  0.113281  0.054688
# 655903       LB13 2022-09-13 23:55:44.903000+00:00  0.113281 -0.023438
# 655904       LB13 2022-09-13 23:55:44.935000+00:00  0.156250 -0.027344
# 655905       LB13 2022-09-13 23:55:44.967000+00:00  0.164063 -0.046875
# 655906       LB13        2022-09-13 23:55:45+00:00 -1.066406  0.070313
#
#            acc_z    label
# 0       1.628906  unknown
# 1      -1.781250  unknown
# 2       0.015625  unknown
# ...

# %%
def plot_two_data_segments(data, start_idx, lenght, label_name = "l_val"):
    
    fig = plt.figure(num=1, figsize=(50,30), dpi=300)
    axL = fig.add_axes([0, 0, 1, 1])
    plot_one_data_segment(axL, data, start_idx, lenght, label_name = label_name)
    fig.savefig(r"G:\JaimeMorales\Codes\biodata\codes\figs\timeseries.svg", format = 'svg', dpi=500, bbox_inches = 'tight')
    fig.tight_layout()
    #fig.show()
    
def plot_one_data_segment(ax, data, start_idx, length, label_name = "label"):
    if start_idx + length > len(data) - 1:
        start_idx = len(data) - 1 - length
    if start_idx < 0:
        start_idx = 0
    ax.plot(data["timestamp"][start_idx:start_idx + length], data['acc_x'][start_idx:start_idx + length], '-' , color = 'red', linewidth=12)
    ax.plot(data["timestamp"][start_idx:start_idx + length], data['acc_y'][start_idx:start_idx + length], '-' , color = 'green', linewidth=12)
    ax.plot(data["timestamp"][start_idx:start_idx + length], data['acc_z'][start_idx:start_idx + length], '-' , color = 'blue', linewidth=12)
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
    ax.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False)
    #ax.set_xlabel("time [s]")

# %%
plot_two_data_segments(viz_df, 0, 2000)
